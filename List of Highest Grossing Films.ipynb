# %% [markdown]
# # Import Libraries

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import pandas as pd

# %% [markdown]
# # Get html text out of URL

# %%
url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
r = requests.get(url).text

# %% [markdown]
# # Extract required table as Dataframe

# %%
soup = BeautifulSoup(r,"html.parser")
table = soup.find_all("table")[0]
data = pd.DataFrame(columns = ["Rank","Peak","Title","Gross","Year"])
for i in table.tbody.find_all('tr'):
    col = i.find_all("td")
    if col != []:
        title = i.find('a',href = True).get('title')
        data = data.append({"Rank" : col[0].text.strip(),"Peak" : col[1].text.strip(),"Title" : title,"Gross" : col[2].text.strip(),"Year" : col[3].text.strip()},ignore_index = True)
data
# Out:
#    Rank   Peak                                            Title  \
# 0     1      1                               Avatar (2009 film)
# 1     2      1                                Avengers: Endgame
# 2     3      1                              Titanic (1997 film)
# 3     4      3                     Star Wars: The Force Awakens
# 4     5      4                           Avengers: Infinity War
# 5     6      6                          Spider-Man: No Way Home
# 6     7      3                                   Jurassic World
# 7     8      7                        The Lion King (2019 film)
# 8     9      3                         The Avengers (2012 film)
# 9    10      4                                        Furious 7
# 10   11     10                                        Frozen II
# 11   12      5                          Avengers: Age of Ultron
# 12   13      9                             Black Panther (film)
# 13   14      3    Harry Potter and the Deathly Hallows – Part 2
# ...
